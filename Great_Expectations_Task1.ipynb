# %% [markdown]
# # Great Expectations Task

# %% [markdown]
# ## 1. Install Great Expectations Library

# %%
# %pip install great_expectations
# Out:
# Requirement already satisfied: great_expectations in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (1.15.2)
# Requirement already satisfied: altair<7.0.0,>=5.0.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (6.0.0)
# Requirement already satisfied: cryptography>=3.2 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (46.0.7)
# Requirement already satisfied: jinja2>=3 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (3.1.6)
# Requirement already satisfied: jsonschema>=2.5.1 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (4.26.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (3.26.2)
# Requirement already satisfied: mistune>=0.8.4 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (3.2.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (2.4.4)
# Requirement already satisfied: packaging in c:\users\jayde\appdata\roaming\python\python313\site-packages (from great_expectations) (26.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (3.0.2)
# Requirement already satisfied: pydantic>=1.10.7 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (2.12.5)
# Requirement already satisfied: pyparsing!=3.2.4,>=2.4 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jayde\appdata\roaming\python\python313\site-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (2.33.1)
# Requirement already satisfied: ruamel.yaml>=0.16 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (0.19.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (1.17.1)
# Requirement already satisfied: tqdm>=4.59.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (4.15.0)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from altair<7.0.0,>=5.0.0->great_expectations) (2.19.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.2->great_expectations) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3->great_expectations) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.5.1->great_expectations) (0.30.0)
# Requirement already satisfied: tzdata in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.3.0->great_expectations) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.7->great_expectations) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=1.10.7->great_expectations) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\jayde\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.1->great_expectations) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->great_expectations) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->great_expectations) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->great_expectations) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->great_expectations) (2026.2.25)
# Requirement already satisfied: colorama in c:\users\jayde\appdata\roaming\python\python313\site-packages (from tqdm>=4.59.0->great_expectations) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\jayde\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=3.2->great_expectations) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\jayde\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# ##2. Import Necessary Libraries

# %%
import pandas as pd
import great_expectations as gx

# %% [markdown]
# ##3. Load Labels.csv

# %% [markdown]
# Download and upload the [Labels.csv](https://github.com/zubxxr/SOFE3980U-Lab5/blob/main/Labels.csv) into this notebook, and then load the file.

# %%
#from google.colab import files #Upload csv file to notebook
#uploaded = files.upload()

import pandas as pd
df = pd.read_csv("Labels.csv") #read csv file

# %% [markdown]
# ##4. Preview the Dataset

# %%
df.head()
# Out:
#     Timestamp  Car1_Location_X  Car1_Location_Y  Car1_Location_Z  \
# 0  1736796157       -51.402977              143         0.596902
# 1  1736796167       -53.819637              143         0.596902
# 2  1736796178       -50.239144              143         0.596902
# 3  1736796188       -53.707220              143         0.596902
# 4  1736796198       -52.053721              143         0.596902
#
#    Car2_Location_X  Car2_Location_Y  Car2_Location_Z Occluded_Image_view  \
# 0       -59.320270              140         0.596902           A_001.png
# 1       -59.196568              140         0.596902           A_002.png
# 2       -56.744479              140         0.596902           A_003.png
# 3       -57.309380              140         0.596902           A_004.png
# 4       -59.545897              140         0.596902           A_005.png
#
#   Occluding_Car_view Ground_Truth_View  pedestrianLocationX_TopLeft  \
# 0          B_001.png         C_001.png                          593
# 1          B_002.png         C_002.png                          579
# 2          B_003.png         C_003.png                          854
# 3          B_004.png         C_004.png                          549
# 4          B_005.png         C_005.png                          524
#
#    pedestrianLocationY_TopLeft  pedestrianLocationX_BottomRight  \
# 0                          361                              610
# 1                          368                              594
# 2                          720                              854
# 3                          368                              567
# 4                          368                              537
#
#    pedestrianLocationY_BottomRight
# 0                              410
# 1                              415
# 2                              720
# 3                              425
# 4                              413

# %% [markdown]
# ##5. Set Up Great Expectations Context and Data Source

# %%
context = gx.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

# %% [markdown]
# ##6. Define and Create a Data Batch

# %%
batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": df})

# %% [markdown]
# ##7. Define Three Expectations for Column Values

# %% [markdown]
# Using this [link](https://greatexpectations.io/expectations/), choose three expectation functions and apply them to the labels dataset in a relevant manner.
#
# You should replace the 'ExpectColumnValuesToBeBetween' function with other functions you select from the link.
#
# You can also check the format/parameters required of each function when you click "See more" on the function.

# %%
## Original Function
expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="column", min_value=0, max_value=20
)

## Example Function

## This function only requires a column parameter, and not a max or min value
expectation = gx.expectations.ExpectColumnValuesToBeUnique(
    column="column"
)

# %% [markdown]
# ### Expectation 1

# %%
# Expect Timstamps to contain numeric values

expectation = gx.expectations.ExpectColumnValuesToBeInTypeList(
    column = "Timestamp",
    type_list = ["int64", "float64"]
)

# %% [markdown]
# ### Validate Data Against Expectation 1

# %%
## Validate
validation_results = batch.validate(expectation)
print(validation_results)
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_in_type_list",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "Timestamp",
#       "type_list": [
#         "int64",
#         "float64"
#       ]
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "observed_value": "int64"
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Expectation 2

# %%
# Expect image filenames to follow the same naming scheme
expectation = gx.expectations.ExpectColumnValuesToMatchRegex(
    column = "Occluded_Image_view",
    regex = "^[A-Z]_[0-9]{3}\.png$"
)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\jayde\AppData\Local\Temp\ipykernel_8960\2369027298.py:4: SyntaxWarning: invalid escape sequence '\.'
#   regex = "^[A-Z]_[0-9]{3}\.png$"

# %% [markdown]
# ### Validate Data Against Expectation 2

# %%
# Validate
validation_result = batch.validate(expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_match_regex",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "Occluded_Image_view",
#       "regex": "^[A-Z]_[0-9]{3}\\.png$"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Expectation 3

# %%
# Expect Timestamps to be unique for each row
expectation = gx.expectations.ExpectColumnValuesToBeUnique(
    column = "Timestamp"
)

# %% [markdown]
# ### Validate Data Against Expectation 3

# %%
# Validate
validation_result = batch.validate(expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "success": true,
#   "expectation_config": {
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "Timestamp"
#     },
#     "meta": {},
#     "severity": "critical"
#   },
#   "result": {
#     "element_count": 121,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }
